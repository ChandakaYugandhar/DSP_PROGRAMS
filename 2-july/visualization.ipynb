# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Line plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([3,4,7,8,9])
ypoints=np.array([7,8,9,2,30])
plt.plot(xpoints,ypoints,linewidth="10")
plt.show()

# %%
plt.plot([4,200],[4,200],"--")
plt.show()

# %%
ypoints=[3,8,1,10,4,7]
plt.plot(ypoints)
plt.show()

# %%
ypoints=[3,4,8,7,10]
plt.plot(ypoints)
plt.show()

# %%
x=[1,2,3,4,7]
y=[10,20,30,40,70]
plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

country=['USA','INDIA','GERMANY','UK','FRANCE']
GDP_Per_capita=[48000,38000,49000,44000,47000]
plt.bar(country,GDP_Per_capita,color='hotpink')
plt.title('Country vs GDP per capita')
plt.xlabel('country')
plt.ylabel('GDP Per capita')
plt.show()

# %%
y=np.array([34,70,14])
co=["r","b","hotpink"]
plt.pie(y,colors=co,labels=['DSP','WT','CD'])
plt.legend(title='subjects')
plt.show()

# %%
numbers=[0.1,7,1,1.4,2,4,4.8,7,8,9]
plt.hist(numbers,bins=4)
plt.xlabel('numbers')
plt.ylabel('frequency')
plt.show()

# %%
y=np.array([0,1,2,3])
x=np.array([3,8,1,10])
plt.title("label1")
plt.subplot(1,2,1)
plt.plot(x,y)
#plot2
x=np.array([3,8,1,10])
y=np.array([0,1,2,3])
plt.subplot(1,2,2)
plt.pie(x,labels=['A','B','C','D'])
plt.legend()
plt.show()

# %%
x=np.array([3,3,8,8,8,3,3,8,3,8])
y=np.array([3,8,3,8,8,3,8,8,3,3])
plt.plot(x,y,marker="*",mec='b',color="r")

# %%
x=
plt.plot([2,2],[2,8],[2,8],[8,8],[8,8],[8,2],[8,2],[2,2],[2,8],[8,1],
        )
plt.show()
