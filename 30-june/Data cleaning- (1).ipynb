# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
df=pd.read_csv("dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
data1=df.dropna()
print("Old data frame length:", len(df), "\nNew data frame length:", 
       len(data1), "\nNumber of rows with at least 1 NA value: ",
       (len(df)-len(data1)))
# Out:
# Old data frame length: 32
# New data frame length: 29
# Number of rows with at least 1 NA value:  3

# %%
data1=df.dropna()
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
data=df.fillna(14,inplace=True)
data

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd
df=pd.read_csv("dirtydata.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.fillna(11)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df["Calories"].fillna(11,inplace=True)

# %%
x=df["Calories"].mean()
y=df["Calories"].fillna(x,inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import pandas as pd

df = pd.read_csv('dirtydata.csv')

x = df["Calories"].mean()
x
# Out:
# 304.68

# %%
df["Date"].fillna(x, inplace = True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130    409.10
# 1         60  '2020/12/02'    117       145    479.00
# 2         60  '2020/12/03'    103       135    340.00
# 3         45  '2020/12/04'    109       175    282.40
# 4         45  '2020/12/05'    117       148    406.00
# 5         60  '2020/12/06'    102       127    300.00
# 6         60  '2020/12/07'    110       136    374.00
# 7        450  '2020/12/08'    104       134    253.30
# 8         30  '2020/12/09'    109       133    195.10
# 9         60  '2020/12/10'     98       124    269.00
# 10        60  '2020/12/11'    103       147    329.30
# 11        60  '2020/12/12'    100       120    250.70
# 12        60  '2020/12/12'    100       120    250.70
# 13        60  '2020/12/13'    106       128    345.30
# 14        60  '2020/12/14'    104       132    379.30
# 15        60  '2020/12/15'     98       123    275.00
# ...

# %%
df["Calories"].fillna(x)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#binning
import pandas as pd
mani={
    "name":['mani','raghu','raju','ravi','fftt','ggh','ytff'],
    "age":[10,3,43,55,78,98,66]
}
df=pd.DataFrame(mani)
df
# Out:
#     name  age
# 0   mani   10
# 1  raghu    3
# 2   raju   43
# 3   ravi   55
# 4   fftt   78
# 5    ggh   98
# 6   ytff   66

# %%
df['Age Group'] = pd.cut(
    df['age'], 
    [0, 17, 45, 64, 100], 
    labels=['0-18 years old', '18-45 years old', '45-65 years old','65+ years old']
)
print(df.head())
# Out:
#     name  age        Age Group
# 0   mani   10   0-18 years old
# 1  raghu    3   0-18 years old
# 2   raju   43  18-45 years old
# 3   ravi   55  45-65 years old
# 4   fftt   78    65+ years old

# %%
import pandas as pd
df=pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
bins=[0,25,40,50,75,100]
group_names=['fail','near to fail','avg','good','brilliant']
df["result"]=pd.cut(df["math score"],bins,labels=group_names)
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score     result
# 0                    none          72             72             74       good
# 1               completed          69             90             88       good
# 2                    none          90             95             93  brilliant
# 3                    none          47             57             44        avg
# 4                    none          76             78             75  brilliant

# %%
group=df.groupby("gender")
for name,grp in group:
    print(name)
# Out:
# female
# male

# %%
df.head(5)
print(grp)
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 18    male        group C             master's degree  free/reduced
# 20    male        group D                 high school      standard
# 22    male        group D                some college      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# ...

# %%
group.get_group("male")
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 3     male        group A          associate's degree  free/reduced
# 4     male        group C                some college      standard
# 7     male        group B                some college  free/reduced
# 8     male        group D                 high school  free/reduced
# 10    male        group C          associate's degree      standard
# 11    male        group D          associate's degree      standard
# 13    male        group A                some college      standard
# 16    male        group C                 high school      standard
# 18    male        group C             master's degree  free/reduced
# 20    male        group D                 high school      standard
# 22    male        group D                some college      standard
# 24    male        group D           bachelor's degree  free/reduced
# 25    male        group A             master's degree  free/reduced
# ...

# %%
import pandas as pd
df=pd.read_csv("big_mart_sales.csv")
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.isna()#check wheather the it has missing values or not
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# 5               False        False             False            False
# 6               False        False             False            False
# 7               False         True             False            False
# 8               False        False             False            False
# 9               False        False             False            False
# 10              False        False             False            False
# 11              False        False             False            False
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
x=df["Item_Weight"].mean()
# Out:
# 12.857645184136183

# %%
y=df["Item_Weight"].fillna(x)

# %%
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df["Item_Weight"].value_counts()
# Out:
# 12.857645    8523
# Name: Item_Weight, dtype: int64

# %%
df["Outlet_Size"].value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df["Outlet_Size"].mode()
# Out:
# 0    Medium
# dtype: object

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15    12.857645          Low Fat         0.016047
# 1           DRC01    12.857645          Regular         0.019278
# 2           FDN15    12.857645          Low Fat         0.016760
# 3           FDX07    12.857645          Regular         0.000000
# 4           NCD19    12.857645          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009         NaN               Tier 3
# ...

# %%
df["Outlet_Size"].fillna("medium",inplace=True)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15    12.857645          Low Fat         0.016047
# 1           DRC01    12.857645          Regular         0.019278
# 2           FDN15    12.857645          Low Fat         0.016760
# 3           FDX07    12.857645          Regular         0.000000
# 4           NCD19    12.857645          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      medium               Tier 3
# ...

# %%
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %%
mapping={
    'Low Fat':'LF', 
    'LF':'LF',
    'low fat':'LF',
    'Regular':'R',
    'reg':'R'
}

# %%
df["Item_Fat_Content"]=df["Item_Fat_Content"].map(mapping)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15    12.857645               LF         0.016047
# 1           DRC01    12.857645                R         0.019278
# 2           FDN15    12.857645               LF         0.016760
# 3           FDX07    12.857645                R         0.000000
# 4           NCD19    12.857645               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      medium               Tier 3
# ...

# %%
df["Item_Fat_Content"].value_counts()
# Out:
# LF    5517
# R     3006
# Name: Item_Fat_Content, dtype: int64

# %%
df["rupees in dollars"]=df["Item_MRP"].apply(lambda x: x/74)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15    12.857645               LF         0.016047
# 1           DRC01    12.857645                R         0.019278
# 2           FDN15    12.857645               LF         0.016760
# 3           FDX07    12.857645                R         0.000000
# 4           NCD19    12.857645               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      medium               Tier 3
# ...

# %%
df["Item_MRP"]=df["Item_MRP"].apply(lambda x:x*5)
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15    12.857645               LF         0.016047
# 1           DRC01    12.857645                R         0.019278
# 2           FDN15    12.857645               LF         0.016760
# 3           FDX07    12.857645                R         0.000000
# 4           NCD19    12.857645               LF         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  12490.46            OUT049
# 1            Soft Drinks   2413.46            OUT018
# 2                   Meat   7080.90            OUT049
# 3  Fruits and Vegetables   9104.75            OUT010
# 4              Household   2693.07            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      medium               Tier 3
# ...

# %%
df=pd.get_dummies(df)
df.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0    12.857645         0.016047  12490.46                       1999
# 1    12.857645         0.019278   2413.46                       2009
# 2    12.857645         0.016760   7080.90                       1999
# 3    12.857645         0.000000   9104.75                       1998
# 4    12.857645         0.000000   2693.07                       1987
#
#    Item_Outlet_Sales  rupees in dollars  Item_Identifier_DRA12  \
# 0          3735.1380           3.375800                      0
# 1           443.4228           0.652286                      0
# 2          2097.2700           1.913757                      0
# 3           732.3800           2.460743                      0
# 4           994.7052           0.727857                      0
#
#    Item_Identifier_DRA24  Item_Identifier_DRA59  Item_Identifier_DRB01  ...  \
# 0                      0                      0                      0  ...
# ...

# %%
df.shape
# Out:
# (8523, 1602)

# %%
df.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0    12.857645         0.016047  12490.46                       1999
# 1    12.857645         0.019278   2413.46                       2009
# 2    12.857645         0.016760   7080.90                       1999
# 3    12.857645         0.000000   9104.75                       1998
# 4    12.857645         0.000000   2693.07                       1987
#
#    Item_Outlet_Sales  rupees in dollars  Item_Identifier_DRA12  \
# 0          3735.1380           3.375800                      0
# 1           443.4228           0.652286                      0
# 2          2097.2700           1.913757                      0
# 3           732.3800           2.460743                      0
# 4           994.7052           0.727857                      0
#
#    Item_Identifier_DRA24  Item_Identifier_DRA59  Item_Identifier_DRB01  ...  \
# 0                      0                      0                      0  ...
# ...

# %%
import pandas as pd
df=pd.read_csv("big_mart_sales.csv")
df.loc[df.Outlet_Establishment_Year==1987].head()
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4            NCD19         8.93          Low Fat         0.000000
# 6            FDO10        13.65          Regular         0.012741
# 14           FDF32        16.35          Low Fat         0.068024
# 20           FDN22        18.85          Regular         0.138190
# 27           DRJ59        11.65          low fat         0.019356
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 4               Household   53.8614            OUT013
# 6             Snack Foods   57.6588            OUT013
# 14  Fruits and Vegetables  196.4426            OUT013
# 20            Snack Foods  250.8724            OUT013
# 27            Hard Drinks   39.1164            OUT013
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 4                        1987        High               Tier 3
# 6                        1987        High               Tier 3
# ...

# %%
df.loc[(df.Outlet_Establishment_Year==1987)&(df.Item_Type=="Canned")].head()
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 44            FDL50       12.150          Regular         0.042278    Canned
# 52            FDR13        9.895          Regular         0.028697    Canned
# 105           FDH14       17.100          Regular         0.046770    Canned
# 246           FDY25       12.000          Low Fat         0.033946    Canned
# 663           FDG38        8.975          Regular         0.052685    Canned
#
#      Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 44   126.5046            OUT013                       1987        High
# 52   117.0492            OUT013                       1987        High
# 105  141.1838            OUT013                       1987        High
# 246  179.3976            OUT013                       1987        High
# 663   83.3224            OUT013                       1987        High
#
#     Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.loc[(df.Outlet_Establishment_Year==1987)|(df.Item_Type=="Canned")]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# 29             FDC14          NaN          Regular         0.072222
# 41             FDK43        9.800          Low Fat         0.026818
# 43             FDC02       21.350          Low Fat         0.069103
# 44             FDL50       12.150          Regular         0.042278
# 47             FDV49       10.000          Low Fat         0.025880
# 51             FDM40       10.195          Low Fat         0.159804
# 52             FDR13        9.895          Regular         0.028697
# 59             FDI26          NaN          Low Fat         0.061082
# ...

# %%
df.loc[(df.Outlet_Establishment_Year!=1987)].head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 5           FDP36       10.395          Regular         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 5           Baking Goods   51.4008            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.loc[(df.Outlet_Establishment_Year==1987)|(df.Item_Type=="Canned")|(df.Item_Weight==9.300)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 4              NCD19        8.930          Low Fat         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 14             FDF32       16.350          Low Fat         0.068024
# 20             FDN22       18.850          Regular         0.138190
# 27             DRJ59       11.650          low fat         0.019356
# 29             FDC14          NaN          Regular         0.072222
# 41             FDK43        9.800          Low Fat         0.026818
# 43             FDC02       21.350          Low Fat         0.069103
# 44             FDL50       12.150          Regular         0.042278
# 47             FDV49       10.000          Low Fat         0.025880
# 51             FDM40       10.195          Low Fat         0.159804
# 52             FDR13        9.895          Regular         0.028697
# ...

# %%
df.loc[df.Outlet_Establishment_Year.isin([1987,1998,1999])].head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
# 6           FDO10        13.65          Regular         0.012741
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
# 6            Snack Foods   57.6588            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 2                       1999      Medium               Tier 1
# ...

# %%
columns=["Item_Weight","Item_Fat_Content","Item_Type"]
df.loc[df.Outlet_Establishment_Year.isin([1987,1998,1999],"Item_Weight","Item_Fat_Content","Item_Type")]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-63e03c60554c> in <module>
#       1 columns=["Item_Weight","Item_Fat_Content","Item_Type"]
# ----> 2 df.loc[df.Outlet_Establishment_Year.isin([1987,1998,1999],"Item_Weight","Item_Fat_Content","Item_Type")]
#
# TypeError: isin() takes 2 positional arguments but 5 were given

# %%
df.select_dtypes("float").head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0         9.30         0.016047  249.8092          3735.1380
# 1         5.92         0.019278   48.2692           443.4228
# 2        17.50         0.016760  141.6180          2097.2700
# 3        19.20         0.000000  182.0950           732.3800
# 4         8.93         0.000000   53.8614           994.7052

# %%
df.set_index("Item_Identifier",inplace=True,drop=True)
df.loc["FDA15"]
# Out:
#                  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# Item_Identifier
# FDA15                    9.3          Low Fat         0.016047     Dairy
# FDA15                    9.3          Low Fat         0.016055     Dairy
# FDA15                    9.3          Low Fat         0.016019     Dairy
# FDA15                    9.3          Low Fat         0.016088     Dairy
# FDA15                    9.3          Low Fat         0.026818     Dairy
# FDA15                    9.3          Low Fat         0.016009     Dairy
# FDA15                    NaN          Low Fat         0.015945     Dairy
# FDA15                    9.3               LF         0.016113     Dairy
#
#                  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# Item_Identifier
# FDA15            249.8092            OUT049                       1999
# FDA15            250.2092            OUT045                       2002
# ...

# %%
df.loc[["FDA15","FDX07"],'Item_Fat_Content']
# Out:
# Item_Identifier
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15    Low Fat
# FDA15         LF
# FDX07    Regular
# FDX07    Regular
# FDX07    Regular
# FDX07    Regular
# FDX07    Regular
# FDX07    Regular
# Name: Item_Fat_Content, dtype: object

# %%
d=df.sort_values(["Item_Weight"]).head()
d
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7808           FDP40        4.555          Regular         0.034329
# 4430           FDP40        4.555          Regular         0.034357
# 3489           FDP40        4.555          Regular         0.034351
# 4400           FDP40        4.555          Regular         0.034411
# 3077           DRE12        4.590          Low Fat         0.070767
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7808  Frozen Foods  110.1544            OUT013                       1987
# 4430  Frozen Foods  112.6544            OUT046                       1997
# 3489  Frozen Foods  112.7544            OUT035                       2004
# 4400  Frozen Foods  111.3544            OUT049                       1999
# 3077   Soft Drinks  111.9860            OUT035                       2004
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-9baf0daa5fc6> in <module>
# ----> 1 df.sort_values()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'
